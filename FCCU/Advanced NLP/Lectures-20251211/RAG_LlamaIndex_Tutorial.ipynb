# %% [markdown]
# At its core, LlamaIndex contains a toolkit designed to easily connect LLM’s with your external data.

# %%
# !pip install llama-index pypdf sentence_transformers llama-index-question-gen-openai -q

# %%
import os
import openai
from IPython.display import display
import textwrap
from llama_index.core import Settings, get_response_synthesizer
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import VectorStoreIndex,SimpleDirectoryReader,ServiceContext,PromptTemplate
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine
from google.colab import userdata


# openai.api_key = "sk-oK2lHkqcDrd1MJFCrvd4VeKIc9-UTySVUtTBZAGb22T3BlbkFJNAijMZvmUKlBUW5XWMkudjAGZBNHpWy3vXS0g612UA"
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# for using openai api
Settings.llm = OpenAI(model = 'gpt-4o-mini')
Settings.embed_model = OpenAIEmbedding(model="text-embedding-3-large")

# # for using locally deployed models using ollama
# Settings.llm = Ollama(model="deepseek-r1", request_timeout=120.0)
# Out:
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validate_default' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'validate_default' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %% [markdown]
# # Naive RAG

# %% [markdown]
# https://gpt-index.readthedocs.io/en/latest/guides/primer/index_guide.html

# %%
# Loading the data (you can add any folder name here)
documents = SimpleDirectoryReader('handbook').load_data()

# Indexing and craeting vector store
index = VectorStoreIndex.from_documents(documents, show_progress= True)

# Retreived the relevant nodes from index
retriever = VectorIndexRetriever(index=index, similarity_top_k=5,)

response_synthesizer = get_response_synthesizer(
    response_mode="simple_summarize",
)

# Retreival and Response
simple_query_engine = RetrieverQueryEngine(
    retriever=retriever,
    response_synthesizer=response_synthesizer,
)
# Out:
# Parsing nodes:   0%|          | 0/336 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/336 [00:00<?, ?it/s]

# %%
response = simple_query_engine.query("What are the requirements for CS BS degree.")
print(textwrap.fill(response.response, width=80))
# Out:
# To obtain a Bachelor of Science in Computer Science (BS CS) degree, students
# must complete a total of 132 credits, which includes the following components:
# 1. **Core Courses**: 58 credits (18 courses) 2. **Supporting Courses**: 22
# credits (7 courses) 3. **Computing Electives**: 12 credits (4 courses) 4.
# **General Education**: 47 credits 5. **University Electives**: 6 credits (2
# courses)  Additionally, students must fulfill specific course requirements,
# including a lab course in the Science and Mathematics category as part of
# General Education.

# %%
response = simple_query_engine.query("List down all the requirements for Double Major, in bullets")
print(response)
# Out:
# - Students are allowed to pursue more than one major.
# - The Higher Education Commission (HEC) recognizes only the first major listed on the transcript.
# - If a student intends to graduate with multiple majors or a combination of a major and a minor, all requirements must be completed according to the same catalog.

# %% [markdown]
# # Cases where naive RAG can fail

# %%
response = simple_query_engine.query("How many courses are offered by FCCU")
print(textwrap.fill(response.response, width=80))
# Out:
# FCCU offers foreign language courses at two levels in four languages: French,
# German, Chinese, and Korean. Additionally, there are various courses across
# different departments as indicated in the catalog. However, the exact total
# number of courses offered is not specified in the provided information.

# %%
response = simple_query_engine.query("What is this text about?")
print(textwrap.fill(response.response, width=80))
# Out:
# The text provides an overview of various courses offered in a Bachelor’s Degree
# Program, focusing on literature, drama, poetry, linguistics, and the humanities.
# It outlines course descriptions, prerequisites, and the educational philosophy
# of the institution, emphasizing the importance of critical thinking,
# communication skills, and a commitment to lifelong learning. Additionally, it
# discusses the expectations of conduct for students and the institution's
# dedication to providing a co-educational environment and an American-style
# education.

# %% [markdown]
# # Response Object

# %%
response.metadata
# Out:
# {'121be295-f238-47e3-aa05-c3ea2a576f56': {'page_label': '144',
#   'file_name': 'Bachelors-Catalog-2025-26-New.pdf',
#   'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf',
#   'file_type': 'application/pdf',
#   'file_size': 4205922,
#   'creation_date': '2025-11-28',
#   'last_modified_date': '2025-11-28'},
#  'cc36068a-f145-4052-8cde-38a7df29e493': {'page_label': '145',
#   'file_name': 'Bachelors-Catalog-2025-26-New.pdf',
#   'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf',
#   'file_type': 'application/pdf',
#   'file_size': 4205922,
#   'creation_date': '2025-11-28',
#   'last_modified_date': '2025-11-28'},
#  '8342bb90-2fad-481b-beb3-be569d99800e': {'page_label': '154',
#   'file_name': 'Bachelors-Catalog-2025-26-New.pdf',
#   'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf',
#   'file_type': 'application/pdf',
#   'file_size': 4205922,
#   'creation_date': '2025-11-28',
#   'last_modified_date': '2025-11-28'},
#  '668ab9bf-b017-41a2-9109-a94af774a216': {'page_label': '21',
#   'file_name': 'Bachelors-Catalog-2025-26-New.pdf',
#   'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf',
#   'file_type': 'application/pdf',
#   'file_size': 4205922,
#   'creation_date': '2025-11-28',
#   'last_modified_date': '2025-11-28'},
#  '09a963d7-e4f4-4faa-b65f-56075282e984': {'page_label': '10',
#   'file_name': 'Bachelors-Catalog-2025-26-New.pdf',
#   'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf',
#   'file_type': 'application/pdf',
#   'file_size': 4205922,
#   'creation_date': '2025-11-28',
#   'last_modified_date': '2025-11-28'}}

# %%
response.source_nodes
# Out:
# [NodeWithScore(node=TextNode(id_='121be295-f238-47e3-aa05-c3ea2a576f56', embedding=None, metadata={'page_label': '144', 'file_name': 'Bachelors-Catalog-2025-26-New.pdf', 'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf', 'file_type': 'application/pdf', 'file_size': 4205922, 'creation_date': '2025-11-28', 'last_modified_date': '2025-11-28'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='bec1f71a-b64f-48e8-ad38-dd89aa20ff53', node_type='4', metadata={'page_label': '144', 'file_name': 'Bachelors-Catalog-2025-26-New.pdf', 'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf', 'file_type': 'application/pdf', 'file_size': 4205922, 'creation_date': '2025-11-28', 'last_modified_date': '2025-11-28'}, hash='2923d74ffa85bb1ee3634155a05debf5bd12a280ee4586cc14eac8c0279e49c4')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Bachelor’s Degree Program Catalog l Page 143  \nComputer Sciences, and Natural Sciences to reflect upon the entanglements of science, \ntechnology, and humanity in the contemporary world. It is aimed at informing and educating \nstudents about the dynamics of the genre of Science Fiction by critically analy zing seminal \nnovels written in the 19th, 20th, and 21st centuries. During the classes, students will discuss the \nrepercussions of the increasing enmeshment of humans with technology and its possible \nfutures. \n \nENGL 307: Classical Drama (3 credits) \nPrerequisites: ENGL 201 \nThis course brings a critical awareness of Drama as a genre or a tradition with focus on its \norigin in Greece and onwards. The course aims to review and analyze the nature and function \nof ancient Greek and Roman drama in its theatrical, historical and social context. The texts will \nbe selected from the major dramatists such as Aeschylus, Sophocles, Euripides, Aristophanes, \nSeneca and others from classical antiquity whose works are preserved. Through all of this, our \ngoal will be to reconstruct as fully as possible the evolution of ancient play-making. The main \nobjective will be to integrate, as broadly as possible, the picture we receive of classical drama \ninto that of ancient history, society and thought. \n \nENGL 308: Elizabethan Drama (3 Credits) \nPrerequisites: ENGL 201 \nThis course explores English drama from the Elizabethan to Jacobean Age, with attention to \nsuch playwrights as Lyly, Kyd, Marlowe, Ben Jonson, and Shakespeare. Plays will be selected \nfrom these playwrights to create a critical awareness in the students regarding the questions of \ngenre, tradition, innovation and elements of universality in these Elizabethan plays. \n \nENGL 310: British Romantic Poetry (3 Credits) \nPrerequisites: ENGL 201 \nThis course especially covers a critical survey of the Romantic Movement and prominent \nromantic poets. It will describe the distinctive position that the English Romantic poets \ncelebrate in this movement. This course may include selected poems by the roman tic poets \nsuch as William Blake, William Wordsworth, S.T. Coleridge, John Keats, P.B. Shelley and \nothers. \n \nENGL 315: Poetry I (3 credits) \nPrerequisite: ENGL 201 \nIn this course, students will explore the history of English poetry, looking at its changing forms \nin the Elizabethan, Jacobean, Restoration, Neoclassical, Reflective, Pre -Romantic, Romantic \nand Victorian ages. \n \nENGL 317: Existential Philosophy and Literature \nPrerequisite: ENGL 201 \nThe most distinctive focus of existentialism (or existential philosophy) is the nature and \nmeaning of human existence. Why do we exist? What is our purpose in life? What is the \nultimate meaning of life or is there even one to think about? These questions a re ...
#  NodeWithScore(node=TextNode(id_='cc36068a-f145-4052-8cde-38a7df29e493', embedding=None, metadata={'page_label': '145', 'file_name': 'Bachelors-Catalog-2025-26-New.pdf', 'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf', 'file_type': 'application/pdf', 'file_size': 4205922, 'creation_date': '2025-11-28', 'last_modified_date': '2025-11-28'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='6b67fb2d-f5b2-4e68-ba17-85b2e57b9c02', node_type='4', metadata={'page_label': '145', 'file_name': 'Bachelors-Catalog-2025-26-New.pdf', 'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf', 'file_type': 'application/pdf', 'file_size': 4205922, 'creation_date': '2025-11-28', 'last_modified_date': '2025-11-28'}, hash='286841a953f9e2c684676c49ea4575d8d405f1ac76e43c5e51c9f00426e157ef')}, metadata_template='{key}: {value}', metadata_separator='\n', text="Bachelor’s Degree Program Catalog l Page 144  \nwell as mind-boggling to say the least. These questions sometimes lead us to what is infamously \nknown as “Existential Crisis”. But why does this crisis arise in the first place, is an overarching \nidea waiting to be dissected on an individual as well as col lective level. While many avenues \nexist within Existentialism. \n \nENGL 318: The Art of Truth”: Creative Nonfiction (3 credits) \nPrerequisite: ENGL 201 \nThis course will familiarize students with contemporary examples of creative nonfiction, also \ncalled the fourth genre or narrative nonfiction. Students will read different sub-genres of CNF \nlike the personal essay, literary journalism, creative cultural cr iticism, and nature and travel \nwriting etc. They will also try their hand at writing in these sub-genres. \n \nENGL 322: American Prose and Fiction (3 credits) \nPrerequisites: ENGL 201 \nThis course is designed to conduct an in-depth survey and exploration of leading developments \nin fiction and non-fiction prose in the United States in various ages. \n \nENGL 323: American Poetry (3 Credits) \nPrerequisites: ENGL 201 \nThe course offers a general survey of American poetry representing various poets such as \nWhitman, Emily Dickenson, Robert Frost, Sylvia Plath, Adrienne Rich others. \n \nENGL 325: American Drama (3 credits) \nPrerequisites: ENGL 201 \nThis course offers a selective study of the cross section of American playwrights. The idea is \nto develop a taste and understanding for American Drama in particular. This course aims to \ninclude selected plays from the works of playwrights such as Arthur Mi ller, Tennessee \nWilliams, Eugene O'Neill, Edward Albee, Sam Shepherd, August Wilson, Thornton Wilder \nand others.  \n \nENGL 328: Trauma Literature and Theory (3 credits) \nPrerequisites: ENGL 201 \nThe purpose of this course is to establish a foundational understanding of Trauma Literature & \nTheory in the students. To achieve this purpose, the students will be introduced to Trauma \nLiterary and theoretical texts in English featuring geographical and h istorical contexts. The \ntexts to be studied in this course are selected from the works of Jonathan Safran Foer, Mohsin \nHamid, Don DeLillo, Kamila Shamsie, Khaled Hosseini, Nadeem Aslam, Sorayya Khan, \nBasharat Peer, Dan Fesperman and others. All these write rs, in their works, have depicted the \nvarious aspects of trauma including its traces from the Holocaust, WW II, Indian Partition 1947, \nHiroshima/Nagasaki atomic explosions, the separation of the East & West Pakistan, Kashmir \nConflict and 9/11 attacks followed by terrorism, militancy and War and Terror.", mimetype='text/plain', start_char_idx=0, end_char_idx=2648, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.2543604990 ...
#  NodeWithScore(node=TextNode(id_='8342bb90-2fad-481b-beb3-be569d99800e', embedding=None, metadata={'page_label': '154', 'file_name': 'Bachelors-Catalog-2025-26-New.pdf', 'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf', 'file_type': 'application/pdf', 'file_size': 4205922, 'creation_date': '2025-11-28', 'last_modified_date': '2025-11-28'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='fcc3ab44-4c13-4a35-9f15-e0057c1ecb4f', node_type='4', metadata={'page_label': '154', 'file_name': 'Bachelors-Catalog-2025-26-New.pdf', 'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf', 'file_type': 'application/pdf', 'file_size': 4205922, 'creation_date': '2025-11-28', 'last_modified_date': '2025-11-28'}, hash='e62e0ffc410092d6725adc5a3dd4263c6dd24fdcd55b463c8bffaaf62c28e97d')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Bachelor’s Degree Program Catalog l Page 153  \ntheoretical foundation. CDA mainly focuses on the study of power, dominance and social \ninequality using theoretical and empirical approaches in texts and non-verbal communications, \nwhile providing information as to how they are constructed through social r elations, identity, \nknowledge and power in any written and spoken text in communities, cultures and literature. \nThis makes it a highly trans-disciplinary course which helps to critically analyze both talk and \ntext. \n \nLING 413: Sociolinguistics (3 credits) \nPrerequisites: LING 217 \nThis course addresses the interdependence of language and culture in various sociological \ncontexts and covers basic sociolinguistic theoretical models and methodologies including \nsocial network theory and ethnography. It also focuses on various aspects of human behavior \nand sociocultural interaction that affect language use, and explores diversity in language in \nrelation to age, gender, region, social class, ethnicity and national origin. An exploration of \nattitudes and ideologies about the language varieti es and choices with an emphasis on speech \ncommunity, dialect and vernacular will be of particular importance to understanding this \nrelationship in diverse cultures. \n \nLING 414: Psycholinguistics (3 credits) \nPrerequisites: LING 217 \nThis course focuses on the psychological components of the English language. It covers areas \nsuch as lexical ambiguity, language comprehension, language production, language acquisition \nand methodology to understand and help change human behavioral patterns. Students will learn \nabout the nature of language, how it is used, how it illuminates understanding of the properties \nof the mind and brain and has an influence on human language. \n \nLING 415: Forensic Linguistics (3 credits) \nPrerequisites: LING 217 \nThis course prepares students to examine the complex relationship between language and law \nthrough a multidisciplinary investigation of spoken and written texts, linguistic behavior, \nforensic phonetics and legal issues/scenarios as they relate to detective investigations, criminal \nor civil disputes. The course content will be composed of theories, techniques and observations \nwhich are necessary to analyze linguistic evidence and understand characteristics of legal \nlanguage based on a range of topically rele vant areas, including dispute of meaning and \nutterance, speaker/author profiling, authorship analysis and attribution, voice/text comparison, \nplagiarism detection, forgery, language/behavioral crimes, and courtroom discourse analysis. \n \nLING 422: Corpus Linguistics (3 credits) \nPrerequisites: LING 217 \nThis course aims to provide a general introduction to corpus-based language study by analyzing \nlarge digital colle ...
#  NodeWithScore(node=TextNode(id_='668ab9bf-b017-41a2-9109-a94af774a216', embedding=None, metadata={'page_label': '21', 'file_name': 'Bachelors-Catalog-2025-26-New.pdf', 'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf', 'file_type': 'application/pdf', 'file_size': 4205922, 'creation_date': '2025-11-28', 'last_modified_date': '2025-11-28'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='b51a56ea-cb59-4d82-ac54-12f61acfb275', node_type='4', metadata={'page_label': '21', 'file_name': 'Bachelors-Catalog-2025-26-New.pdf', 'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf', 'file_type': 'application/pdf', 'file_size': 4205922, 'creation_date': '2025-11-28', 'last_modified_date': '2025-11-28'}, hash='736670cab0c973be52c723ab6cdbc73a0a732b38abcf962d97143b8b743c1c4b')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Bachelor’s Degree Program Catalog l Page 20  \nIn addition to individual tutoring, the Writing Center hosts workshops led by experts, focusing \non various aspects of university -level writing and research. These resources aim to enhance \nstudents’ skills and confidence in their academic writing. \n \nDiscipline \nAll students are expected to uphold standards of dignity, self-respect, honesty, and courtesy in \ntheir conduct. Strict adherence to disciplinary standards is mandatory. The Rector’s decisions \nregarding disciplinary matters are final and legally binding on all students. Proctors are \nresponsible for maintaining discipline, enforcing rules of good conduct, and taking necessary \ndisciplinary actions when required. \n \nExpectations of Conduct \n \n1. Rules and Regulations: Students must observe all rules and regulations governing \ntheir studies, including both theoretical and practical components, as established from \ntime to time. \n2. Attendance: Students are required to attend all lectures, laboratory sessions, and \nacademic activities for the courses in which they are enrolled. \n3. Academic Integrity: Acts of dishonesty and cheating, particularly during \nexaminations, are strictly prohibited and will result in punitive action if proven. \n4. Behavioral Standards: Students must refrain from any behavior that poses a threat to \nfellow students, faculty, staff, or any other individuals associated with the University. \n \nDisciplinary Consequences \nStudents involved in any of the following activities will face serious disciplinary consequences, \nwhich may include fines, parental undertakings, suspension, or expulsion from the University \nfor a period of one semester to one year, depending on the severity of the offense: \n \n● Causing, attempting to cause, or threatening physical injury to another person (e.g., \nfighting). \n● Willfully using force against another person, except in self-defense. \n● Possession of dangerous objects that may cause harm or injury (e.g., metal rods, knives, \nfirearms). \n● Selling, possessing, or using alcohol, drugs, intoxicants, or controlled substances. \n● Possessing or smoking tobacco or using any tobacco products. \n● Engaging in hate violence or degrading/inflammatory behavior towards others, \nincluding hazing. \n● Offering to sell or delivering a controlled substance or a substitute. \n● Continued disruption of class or university activities, or repeated defiance of university \nauthorities. \n● Intimidation, bullying, or making threats towards university staff or students. \n \nBy adhering to these guidelines, students contribute to a safe and respectful learning', mimetype='text/plain', start_char_idx=0, end_char_idx=2632, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.2464980401955688),
#  NodeWithScore(node=TextNode(id_='09a963d7-e4f4-4faa-b65f-56075282e984', embedding=None, metadata={'page_label': '10', 'file_name': 'Bachelors-Catalog-2025-26-New.pdf', 'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf', 'file_type': 'application/pdf', 'file_size': 4205922, 'creation_date': '2025-11-28', 'last_modified_date': '2025-11-28'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='dbac5fae-b73a-4fa4-a8e3-4a857d14b69b', node_type='4', metadata={'page_label': '10', 'file_name': 'Bachelors-Catalog-2025-26-New.pdf', 'file_path': '/content/handbook/Bachelors-Catalog-2025-26-New.pdf', 'file_type': 'application/pdf', 'file_size': 4205922, 'creation_date': '2025-11-28', 'last_modified_date': '2025-11-28'}, hash='24fe283d0a39a801f38c44c823a84d94fc2fd00e4322c54de8b1a4b78c23a5b6')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Bachelor’s Degree Program Catalog l Page 9  \npolitical unrest, and the conditions for stable governance and sustainable economic \ndevelopment. Through studies in the humanities, the general education program seeks to help \nstudents explore various perspectives on the central concerns of human existence. The general \neducation program is designed to help students assume increased responsibility for their own \ngrowth, to master the skills that are necessary to understand and deal with a rapidly changing \nand increasingly complex world. The program requires s tudents to take courses in each of the \nfollowing areas of human knowledge: Humanities, Natural Sciences, Social and Behavioral \nSciences, Mathematics and Computer Sciences. \n \nCommitment to Career Preparation \nEnriched with the enduring qualities of a liberal arts education, FCCU seeks to graduate \nstudents who are well -prepared for success in their careers. Through the major field of study \nselected by the student, he or she will receive a basic knowledge of a particular field in enough \ndepth to be successful in entry level positions in a career and to advance successfully to \nincreased levels of responsibility on the job. \n \nHowever, it is impossible to predict what a person will need to know for success in the job \ntwenty years from now, but we do know that in most jobs new knowledge will have to be \nmastered that does not even exist today. Therefore, it is more important to le arn how to learn, \nhow to think, how to solve problems, and how to communicate effectively rather than just \nfocusing narrowly on the content of an academic discipline. The educational program is \ndesigned to help students develop these skills. \n \nCommitment to Co-education \nThe Bachelor’s Degree Programs of FCCU is co-educational. FCCU first admitted women in \n1902, and it seeks to provide a learning environment in which both men and women can learn \neffectively and develop the character traits and personality that will enable them to succeed in \nlater life. The core value of respect for the dignity of each human being is also an important \nconsideration for creating a wholesome and positive atmosphere for learning for both men and \nwomen. \n \nCommitment to Lifelong Learning \nFCCU seeks to prepare students for a lifetime of self -directed learning. This will be essential \nfor success in a rapidly changing and increasingly complex world. The faculty models this \ncommitment by constantly learning about new knowledge in their academic discipline, and by \nparticipating in a variety of professional development programs presented to them by the \nUniversity management to help them learn new approaches to teaching and learning. \n \nCommitment to Providing an American-style Education \nThe proceeding commitments reflect the commitme ...

# %% [markdown]
# # Advanced RAG

# %% [markdown]
# ## SubQuestion Query Engine

# %%
from llama_index.core.query_engine import SubQuestionQueryEngine
from llama_index.core.tools import QueryEngineTool, ToolMetadata
import nest_asyncio

nest_asyncio.apply()

# %%
query_engine_tools = [
    QueryEngineTool(
        query_engine=simple_query_engine,
        metadata=ToolMetadata(
            name="handbook",
            description="FCCU Student Handbook",
        ),
    ),
]

# %%
sub_question_query_engine = SubQuestionQueryEngine.from_defaults(query_engine_tools=query_engine_tools, use_async=True,)

# %%
response = sub_question_query_engine.query("What is this text about")
print(textwrap.fill(response.response, width=80))
# Out:
# Generated 5 sub questions.
# [handbook] Q: What topics are covered in the FCCU Student Handbook?
# [handbook] Q: What are the key policies outlined in the FCCU Student Handbook?
# [handbook] Q: What resources are available to students according to the FCCU Student Handbook?
# [handbook] Q: What are the academic requirements mentioned in the FCCU Student Handbook?
# [handbook] Q: What support services are detailed in the FCCU Student Handbook?
# [handbook] A: The FCCU Student Handbook covers a variety of topics including the dress code, sexual harassment policy, commitment to core values, faculty commitment to students, general education, equality of opportunity, and financial integrity. Additionally, it includes sections on student success, student life, fee structure, financial aid and merit scholarships, academic policies and procedures, academic support, awards, and various academic departments.
# [handbook] A: The FCCU Student Handbook details several support services, including:
#
# 1. **On-Campus Health Services**: Provided by Mercy Health Center, offering treatment for minor injuries and illnesses, confidential medical guidance, health support for chronic conditions, referrals to outside care, and wellness seminars.
#
# 2. **Campus Counseling Center**: Located within the Mercy Health Center, it offers individual counseling, crisis intervention, referrals to professionals, seminars, and access to mental health resources.
#
# 3. **Writing and Communication Center**: This center supports students in their writing and research, offering personalized tutoring and assistance tailored to individual needs.
#
# 4. **Academic Advising Center**: Provides academic support for students, including course selection, career planning, and assistance for those on academic probation.
#
# 5. **Campus Accessibility Committee**: Responsible for arranging accommodations for students with disabilities and providing guidance on support services and best practices for inclusion.
#
# These services aim to enhance the academic and personal well-being of students at FCCU.
# [handbook] A: The key policies outlined in the FCCU Student Handbook include:
#
# 1. **Dress Code**: Students are expected to dress in a clean, neat, and modest manner, reflecting the culture of the university. The FCCU ID card must be displayed at all times on campus.
#
# 2. **Sexual Harassment Policy**: Sexual harassment is deemed unacceptable and includes any unwelcome sexual advances or conduct that is offensive or intimidating. Specific examples of harassment behaviors are provided.
#
# 3. **Commitment to Core Values**: The university emphasizes values such as integrity, excellence, respect for dignity, discipline, fairness, service, and community, which students are encouraged to uphold.
#
# 4. **Commitment of Faculty to Students**: Faculty members are dedicated to student learning and success, providing assistance outside of the classroom without charging for extra help.
#
# 5. **Commitment to General Education**: The university aims to provide a well-rounded education that fosters lifelong learning and responsible citizenship.
#
# 6. **Commitment to Equality of Opportunity**: There is a commitment to non-discrimination based on various factors, ensuring that decisions regarding employment and admission are merit-based.
#
# 7. **Financial Integrity**: FCCU operates as a private, not-for-profit institution, with tuition and fees supporting educational programs, supplemented by donations.
#
# 8. **Academic Policies and Procedures**: This includes the medium of instruction being English, attendance expectations, standards of academic progress, and requirements for maintaining good academic standing.
# [handbook] A: Students at FCCU have access to various resources, including:
#
# 1. **On-Campus Health Services**: The Mercy Health Center provides treatment for minor injuries and illnesses, confidential medical guidance, health support for chronic conditions, referrals to outside care, and wellness seminars.
#
# 2. **Campus Counseling Center**: Located within the Mercy Health Center, this facility offers individual counseling, crisis intervention, workshops, and access to mental health resources.
#
# 3. **Writing and Communication Center**: This center supports students in their writing and research through personalized tutoring, available by appointment or walk-in.
#
# 4. **Student Societies**: A variety of student societies are available, covering interests from psychology to sports, arts, and community service.
#
# 5. **Religious Life**: Facilities and programs for both Muslim and Christian students, including mosques, chapel services, and study groups.
#
# 6. **Sports Programs**: The Sports Office and Sports Society organize intramural sports and competitions across various athletic disciplines, welcoming players of all skill levels.
#
# These resources aim to enhance student well-being, academic success, and community engagement.
# [handbook] A: The academic requirements mentioned include:
#
# 1. **Medium of Instruction**: English is the medium of instruction, and students with deficiencies in English must enroll in pre-university English language courses.
#
# 2. **Class Attendance**: Students are expected to attend all classes and laboratory sessions, with a minimum attendance requirement of 67%. Individual instructors may set higher attendance standards, and failure to meet these may prevent students from taking final examinations.
#
# 3. **Standards of Academic Progress**: Students should complete five courses per semester (15 to 18 credits) with a minimum grade of C or higher to maintain normal progress toward graduation.
#
# 4. **Good Academic Standing**: To remain in good academic standing, students must meet specific CGPA requirements based on their classification:
#    - Freshmen (01-30 credit hours): Minimum CGPA of 1.50
#    - Sophomores (31-60 credit hours): Minimum CGPA of 1.75
#    - Juniors (61-90 credit hours): Minimum CGPA of 2.00
#    - Seniors (90 or more credit hours): Minimum CGPA of 2.00
#
# 5. **Probation and Dismissal**: Students on academic probation must raise their CGPA to the required threshold for good standing. Those on probation for two consecutive semesters will be suspended from co-curricular and sports activities.
#
# 6. **Academic Integrity**: Breaches of academic integrity, such as forgery and plagiarism, will be reviewed by the Academic Integrity Committee, with penalties including fines and hearings.
#
# 7. **Academic Advising**: Each student is assigned an Academic Advisor to assist with course selection and academic progress, and students are encouraged to meet with their advisor at least once per semester.
#
# 8. **Major Requirements**: Students must fulfill the requirements of their chosen major, which includes completing at least 39 credit hours specific to that major.
# This text provides an overview of the FCCU Student Handbook, detailing various
# topics such as policies, resources, academic requirements, and support services
# available to students. It outlines key policies related to dress code, sexual
# harassment, core values, and academic integrity, as well as resources like
# health services, counseling, and writing support. Additionally, it describes
# academic requirements for maintaining good standing and the support services
# designed to enhance student well-being and success.

# %% [markdown]
# # Routing

# %%
from llama_index.core.query_engine import RouterQueryEngine
from llama_index.core.selectors import LLMSingleSelector, LLMMultiSelector
from llama_index.core.selectors import (
    PydanticMultiSelector,
    PydanticSingleSelector,
)

# %%
# Loading and creating index for who book
who_documents = SimpleDirectoryReader('who').load_data()

# Indexing and creating vector store
who_index = VectorStoreIndex.from_documents(who_documents, show_progress= True)

who_query_engine = who_index.as_query_engine()
# Out:
# Parsing nodes:   0%|          | 0/114 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/114 [00:00<?, ?it/s]

# %%
from llama_index.core.tools import QueryEngineTool

lums_tool = QueryEngineTool.from_defaults(
    query_engine=simple_query_engine,
    description=(
        "Provide information on rules and policy of lums"
    ),
)

who_tool = QueryEngineTool.from_defaults(
    query_engine=who_query_engine,
    description=(
        "Provides infromation on self care instructions provided by WHO"
    ),
)

# %%
router_query_engine = RouterQueryEngine(
    selector=PydanticSingleSelector.from_defaults(),
    query_engine_tools=[
        lums_tool,
        who_tool,
    ],
)

# %%
response = router_query_engine.query("who is the VC of lums")
print(response.metadata["selector_result"])
print(textwrap.fill(response.response, width=80))
# Out:
# selections=[SingleSelection(index=0, reason='The question pertains to the rules and policy of LUMS, which may include information about the Vice Chancellor.')]
# The Vice Chancellor of LUMS is Ali Cheema.

# %%
response = router_query_engine.query("importance of mantainging good health")
print(response.metadata["selector_result"])
print(textwrap.fill(response.response, width=80))
# Out:
# selections=[SingleSelection(index=1, reason='The question pertains to maintaining good health, and the self-care instructions provided by WHO are directly related to health maintenance.')]
# Maintaining good health is crucial as it significantly impacts overall well-
# being and quality of life. Good health enables individuals to perform daily
# activities effectively, reduces the risk of chronic diseases, and enhances
# mental and emotional stability. It also contributes to increased productivity
# and longevity, allowing individuals to engage more fully in their communities
# and relationships. Prioritizing health through proper nutrition, regular
# exercise, and preventive care can lead to a healthier population and reduce
# healthcare costs in the long run.

# %% [markdown]
# # Query Rewriting

# %%
from llama_index.core import PromptTemplate

query_gen_str = """\
You are a helpful assistant that generates multiple search queries based on a \
single input query. Generate {num_queries} search queries, one on each line, \
related to the following input query:
Query: {query}
Queries:
"""
query_gen_prompt = PromptTemplate(query_gen_str)

def generate_queries(query: str, llm, num_queries: int = 4):
    response = llm.predict(
        query_gen_prompt, num_queries=num_queries, query=query
    )
    # assume LLM proper put each query on a newline
    queries = response.split("\n")
    return queries


queries = generate_queries("What happened at Interleaf and Viaweb?", Settings.llm)
queries
# Out:
# ['1. History and events surrounding Interleaf and Viaweb companies  ',
#  "2. Key milestones and outcomes of Interleaf and Viaweb's operations  ",
#  '3. The rise and fall of Interleaf and Viaweb in the tech industry  ',
#  '4. Impact of Interleaf and Viaweb on software development and e-commerce']

# %% [markdown]
# # HyDE Query Transform

# %%
from llama_index.core.indices.query.query_transform import HyDEQueryTransform
from llama_index.core.query_engine import TransformQueryEngine

hyde = HyDEQueryTransform(include_original=True)
hyde_query_engine = TransformQueryEngine(simple_query_engine, hyde)

query_str = "What are profits of ABC TECH"

# response = hyde_query_engine.query(query_str)
# print(textwrap.fill(response.response, width=80))

# %%
query_bundle = hyde(query_str)
print(textwrap.fill(query_bundle.custom_embedding_strs[0], width=80))
# Out:
# ABC TECH has experienced significant profits over the past fiscal year, driven
# by several key factors that highlight its robust business model and strategic
# initiatives. The company reported a net profit margin of 25%, which is notably
# higher than the industry average of 15%. This impressive margin can be
# attributed to a combination of innovative product offerings, efficient cost
# management, and a strong market presence.  One of the primary contributors to
# ABC TECH's profitability is its diverse portfolio of technology solutions,
# including software development, cloud services, and cybersecurity products. The
# demand for these services has surged, particularly in the wake of increased
# digital transformation efforts across various sectors. ABC TECH's flagship
# product, a cloud-based platform, has seen a 40% increase in subscriptions,
# significantly boosting recurring revenue streams.  Additionally, ABC TECH has
# implemented rigorous cost-control measures, optimizing operational efficiencies
# and reducing overhead expenses by 10%. This strategic focus on lean operations
# has allowed the company to maintain healthy profit margins even amidst
# fluctuating market conditions.  Furthermore, ABC TECH's commitment to research
# and development has positioned it as a leader in innovation, enabling the
# company to stay ahead of competitors and capture new market opportunities. The
# introduction of cutting-edge technologies, such as artificial intelligence and
# machine learning solutions, has attracted a broader customer base and enhanced
# overall sales.  In summary, ABC TECH's profits are a result of its strategic
# diversification, effective cost management, and continuous innovation, all of
# which have solidified its standing as a profitable player in the technology
# sector.
